# %%
import pandas as pd

# %%
df=pd.read_csv('E:\\post.csv')

# %%
df.head()
# Out:
#   timestamp                     date   day_name  day_of_month month_of_year  \
# 0          12/1/2010 8:26  12/1/2010  Wednesday             1      December
# 1          12/1/2010 8:26  12/1/2010  Wednesday             1      December
# 2          12/1/2010 8:26  12/1/2010  Wednesday             1      December
# 3          12/1/2010 8:26  12/1/2010  Wednesday             1      December
# 4          12/1/2010 8:26  12/1/2010  Wednesday             1      December
#
#   time_of_day(hh:mm:ss) transaction id product id  \
# 0               8:26:00         536365     85123A
# 1               8:26:00         536365      71053
# 2               8:26:00         536365     84406B
# 3               8:26:00         536365     84029G
# 4               8:26:00         536365     84029E
#
#                    product description  quantity sold transaction timestamp  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER              6        12/1/2010 8:26
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 541909 entries, 0 to 541908
# Data columns (total 14 columns):
# timestamp                  541909 non-null object
# date                       541909 non-null object
# day_name                   541909 non-null object
# day_of_month               541909 non-null int64
# month_of_year              541909 non-null object
# time_of_day(hh:mm:ss)      541909 non-null object
# transaction id             541909 non-null object
# product id                 541909 non-null object
# product description        540455 non-null object
# quantity sold              541909 non-null int64
# transaction timestamp      541909 non-null object
# unit price                 541909 non-null float64
# customer id                406829 non-null float64
# transaction country        541909 non-null object
# dtypes: float64(2), int64(2), object(10)
# memory usage: 57.9+ MB

# %%
df['date']=pd.to_datetime(df.date)

# %%
date2011=df[df.date.dt.year==2011]

# %%
date2011.head()
# Out:
#       timestamp                     date day_name  day_of_month month_of_year  \
# 42481          1/4/2011 10:00 2011-01-04  Tuesday             4       January
# 42482          1/4/2011 10:00 2011-01-04  Tuesday             4       January
# 42483          1/4/2011 10:00 2011-01-04  Tuesday             4       January
# 42484          1/4/2011 10:00 2011-01-04  Tuesday             4       January
# 42485          1/4/2011 10:00 2011-01-04  Tuesday             4       January
#
#       time_of_day(hh:mm:ss) transaction id product id  \
# 42481              10:00:00         539993      22386
# 42482              10:00:00         539993      21499
# 42483              10:00:00         539993      21498
# 42484              10:00:00         539993      22379
# 42485              10:00:00         539993      20718
#
#              product description  quantity sold transaction timestamp  \
# 42481    JUMBO BAG PINK POLKADOT             10        1/4/2011 10:00
# ...

# %%
import matplotlib.pyplot as plt
import seaborn as sns
sns.set()

# %%
date2010=df[df.date.dt.year==2010]

# %%
plt.plot(date['quantity sold'],date2011.date)
plt.xlabel('Quantity sold')
plt.ylabel('dates')
plt.title('2011 trends')
# Out:
# Text(0.5,1,u'2011 trends')

# %%
plt.plot(date2010['unit price'],date2010.date)
plt.xlabel('unit price')
plt.ylabel('dates')
plt.title('2010 trends')
# Out:
# Text(0.5,1,u'2010 trends')

# %%
date2010['quantity sold'].sum()
# Out:
# 342228

# %%
date2010['unit price'].sum()
# Out:
# 260520.85000000003

# %%
date2011['quantity sold'].sum()
# Out:
# 4834222

# %%
date2011['unit price'].sum()
# Out:
# 2238283.124

# %%
df[df['quantity sold']>1000]
# Out:
#        timestamp                     date   day_name  day_of_month  \
# 4850           12/2/2010 16:48 2010-12-02   Thursday             2
# 4945           12/2/2010 17:38 2010-12-02   Thursday             2
# 4946           12/2/2010 17:38 2010-12-02   Thursday             2
# 6365           12/3/2010 11:48 2010-12-03     Friday             3
# 16435          12/7/2010 16:43 2010-12-07    Tuesday             7
# 16436          12/7/2010 16:43 2010-12-07    Tuesday             7
# 19871          12/9/2010 10:44 2010-12-09   Thursday             9
# 19980          12/9/2010 11:35 2010-12-09   Thursday             9
# 25920         12/12/2010 12:03 2010-12-12     Sunday            12
# 32671         12/16/2010 10:35 2010-12-16   Thursday            16
# 40060         12/21/2010 13:34 2010-12-21    Tuesday            21
# 52132           1/11/2011 8:43 2011-01-11    Tuesday            11
# 52133           1/11/2011 8:43 2011-01-11    Tuesday            11
# ...

# %%
df.head()
# Out:
#   timestamp                     date   day_name  day_of_month month_of_year  \
# 0          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 1          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 2          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 3          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 4          12/1/2010 8:26 2010-12-01  Wednesday             1      December
#
#   time_of_day(hh:mm:ss) transaction id product id  \
# 0               8:26:00         536365     85123A
# 1               8:26:00         536365      71053
# 2               8:26:00         536365     84406B
# 3               8:26:00         536365     84029G
# 4               8:26:00         536365     84029E
#
#                    product description  quantity sold transaction timestamp  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER              6        12/1/2010 8:26
# ...

# %%
df[df['quantity sold']>0].head()
# Out:
#   timestamp                     date   day_name  day_of_month month_of_year  \
# 0          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 1          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 2          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 3          12/1/2010 8:26 2010-12-01  Wednesday             1      December
# 4          12/1/2010 8:26 2010-12-01  Wednesday             1      December
#
#   time_of_day(hh:mm:ss) transaction id product id  \
# 0               8:26:00         536365     85123A
# 1               8:26:00         536365      71053
# 2               8:26:00         536365     84406B
# 3               8:26:00         536365     84029G
# 4               8:26:00         536365     84029E
#
#                    product description  quantity sold transaction timestamp  \
# 0   WHITE HANGING HEART T-LIGHT HOLDER              6        12/1/2010 8:26
# ...

# %%
df['transaction country'].value_counts()
# Out:
# United Kingdom          495478
# Germany                   9495
# France                    8557
# EIRE                      8196
# Spain                     2533
# Netherlands               2371
# Belgium                   2069
# Switzerland               2002
# Portugal                  1519
# Australia                 1259
# Norway                    1086
# Italy                      803
# Channel Islands            758
# Finland                    695
# Cyprus                     622
# Sweden                     462
# Unspecified                446
# Austria                    401
# Denmark                    389
# Japan                      358
# Poland                     341
# Israel                     297
# USA                        291
# Hong Kong                  288
# Singapore                  229
# Iceland                    182
# Canada                     151
# Greece                     146
# Malta                      127
# United Arab Emirates        68
# ...

# %%
df['unit price'].value_counts()
# Out:
# 1.25       50496
# 1.65       38181
# 0.85       28497
# 2.95       27768
# 0.42       24533
# 4.95       19040
# 3.75       18600
# 2.10       17697
# 2.46       17091
# 2.08       17005
# 0.83       16978
# 4.13       15337
# 1.95       13145
# 1.45       13059
# 2.55       13033
# 1.63       12715
# 3.29       11762
# 0.39        8245
# 5.95        7915
# 0.65        7861
# 0.55        7661
# 4.25        7484
# 7.95        7087
# 5.79        6845
# 4.15        6193
# 9.95        5846
# 8.50        5773
# 8.29        4790
# 4.96        4496
# 0.29        4426
#            ...
# 7.69           1
# 49.46          1
# 5575.28        1
# 159.63         1
# 644.28         1
# 4.48           1
# 1042.84        1
# 1154.67        1
# 103.40         1
# 77.63          1
# 188.15         1
# 19.53          1
# 16.50          1
# 82.73          1
# 12.99          1
# 171.07         1
# 273.79         1
# 126.54         1
# 11.90          1
# 5225.03        1
# 201.84         1
# ...

# %%
df['transaction country'].counts()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-76-9fbf8bf39bba> in <module>()
# ----> 1 df['transaction country'].counts()
#
# C:\Users\user\Anaconda2\lib\site-packages\pandas\core\generic.pyc in __getattr__(self, name)
#    3612             if name in self._info_axis:
#    3613                 return self[name]
# -> 3614             return object.__getattribute__(self, name)
#    3615
#    3616     def __setattr__(self, name, value):
#
# AttributeError: 'Series' object has no attribute 'counts'

# %%
df[df['quantity sold']>5000]
# Out:
#        timestamp                     date day_name  day_of_month  \
# 61619          1/18/2011 10:01 2011-01-18  Tuesday            18
# 74614          1/28/2011 12:03 2011-01-28   Friday            28
# 502122        11/25/2011 15:57 2011-11-25   Friday            25
# 540421          12/9/2011 9:15 2011-12-09   Friday             9
#
#        month_of_year time_of_day(hh:mm:ss) transaction id product id  \
# 61619        January              10:01:00         541431      23166
# 74614        January              12:03:00         542504      37413
# 502122      November              15:57:00         578841      84826
# 540421      December               9:15:00         581483      23843
#
#                    product description  quantity sold transaction timestamp  \
# 61619   MEDIUM CERAMIC TOP STORAGE JAR          74215       1/18/2011 10:01
# 74614                              NaN           5568       1/28/2011 12:03
# ...

# %%
df[df['quantity sold']==80995]
# Out:
#        timestamp                     date day_name  day_of_month  \
# 540421          12/9/2011 9:15 2011-12-09   Friday             9
#
#        month_of_year time_of_day(hh:mm:ss) transaction id product id  \
# 540421      December               9:15:00         581483      23843
#
#                 product description  quantity sold transaction timestamp  \
# 540421  PAPER CRAFT , LITTLE BIRDIE          80995        12/9/2011 9:15
#
#         unit price  customer id transaction country
# 540421        2.08      16446.0      United Kingdom

# %%
df['quantity sold'].
# Out:
#   File "<ipython-input-87-578832f02dec>", line 1
#     df['quantity sold'].
#                         ^
# SyntaxError: invalid syntax

# %%
plt.plot(df['quantity sold'],df['unit price'])

# %%
import numpy as np
np.cov(df['quantity sold'],df['unit price'])
# Out:
# array([[ 4.75593914e+04, -2.60587613e+01],
#        [-2.60587613e+01,  9.36246916e+03]])

# %%
df[df['customer id']==13323].head()
# Out:
#        timestamp                     date day_name  day_of_month  \
# 344759         9/16/2011 13:23 2011-09-16   Friday            16
# 344760         9/16/2011 13:23 2011-09-16   Friday            16
# 344761         9/16/2011 13:23 2011-09-16   Friday            16
# 344762         9/16/2011 13:23 2011-09-16   Friday            16
# 344763         9/16/2011 13:23 2011-09-16   Friday            16
#
#        month_of_year time_of_day(hh:mm:ss) transaction id product id  \
# 344759     September              13:23:00         567097      21485
# 344760     September              13:23:00         567097      22114
# 344761     September              13:23:00         567097      21484
# 344762     September              13:23:00         567097     84029E
# 344763     September              13:23:00         567097      23355
#
#                       product description  quantity sold  \
# 344759   RETROSPOT HEART HOT WATER BOTTLE              6
# ...

# %%
df[df['product id']=='21485']
# Out:
#        timestamp                     date   day_name  day_of_month  \
# 229            12/1/2010 10:19 2010-12-01  Wednesday             1
# 258            12/1/2010 10:39 2010-12-01  Wednesday             1
# 707            12/1/2010 12:08 2010-12-01  Wednesday             1
# 775            12/1/2010 12:22 2010-12-01  Wednesday             1
# 1074           12/1/2010 12:50 2010-12-01  Wednesday             1
# 1324           12/1/2010 13:38 2010-12-01  Wednesday             1
# 1332           12/1/2010 13:45 2010-12-01  Wednesday             1
# 2065           12/1/2010 14:41 2010-12-01  Wednesday             1
# 2076           12/1/2010 14:41 2010-12-01  Wednesday             1
# 3469           12/2/2010 11:02 2010-12-02   Thursday             2
# 5239            12/3/2010 9:49 2010-12-03     Friday             3
# 5358           12/3/2010 10:43 2010-12-03     Friday             3
# 6267           12/3/2010 11:36 2010-12-03     Friday             3
# ...
